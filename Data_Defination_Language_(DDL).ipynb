# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeshv01/SQL-Assignment/blob/main/Data_Defination_Language_(DDL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SQL
# #
# #
# ### DATA DEFINATION LANGUAGE (DDL)

# %% [markdown]
# # 1 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.32 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 2 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.32 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 3 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.33 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 4 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.32 PM (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 5 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.32 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 6 PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.33 PM (1).jpeg](data:image/jpeg;base64,...)

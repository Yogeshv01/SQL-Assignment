# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeshv01/SQL-Assignment/blob/main/Data_Manipulation_Language_(DML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data_Manipulation_Language_(DML)

# %% [markdown]
# # 1_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.33 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 2_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.34 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 3_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.34 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 4_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.34 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 5_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.34 PM (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 6_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.35 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 7_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.35 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 8_PAGE

# %% [markdown]
# ![WhatsApp Image 2022-06-02 at 8.32.35 PM.jpeg](data:image/jpeg;base64,...)

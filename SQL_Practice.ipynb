# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeshv01/SQL-Assignment/blob/main/SQL_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1'st Picture

# %% [markdown]
# ![1st_Pic.png](data:image/png;base64,...)

# %% [markdown]
# # 2nd Picture

# %% [markdown]
# ![2nd_Pic.png](data:image/png;base64,...)

# %% [markdown]
# # 3rd Picture

# %% [markdown]
# ![4th_Pic.png](data:image/png;base64,...)
